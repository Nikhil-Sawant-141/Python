# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Krishna'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.astropy',
#  '.atom',
#  '.bluemix',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.dbshell',
#  '.docker',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.kaggle',
#  '.keras',
#  '.matplotlib',
#  '.mongodb',
#  '.mongorc.js',
#  '.PyCharmCE2019.3',
#  '.pyforest',
#  '.python_history',
#  '.spyder-py3',
#  '3D Objects',
#  'about_me',
#  'actions',
#  'actions.py',
#  'AdobeGCLaunchEvent',
#  'AdobeGCLaunchEvent.db',
#  'Adult dataset Exploration.ipynb',
#  'All about URLs and API',
#  'amazonin_1.csv',
#  'anaconda',
#  'Anaconda3',
#  'ansel',
#  'ANZ Data Analysis',
#  'AppData',
#  'Apple Stocks Data.ipynb',
#  'Application Data',
#  'archive.zip',
#  'Aryan.ipynb',
#  'a_test.csv',
#  'a_train.csv',
#  'Beautiful Soup 4.ipynb',
#  'Binary Classification.ipynb',
#  'Bing Search API .ipynb',
#  'body_image.xls',
#  'carInsurance_test.csv',
#  'carInsurance_train.csv',
#  'CIFAR-10.ipynb',
# ...

# %%
os.rename('SalesKaggle3 (1).csv', 'SalesKaggle.csv')

# %%
os.stat('SalesKaggle.csv')
# Out:
# os.stat_result(st_mode=33206, st_ino=17451448556128433, st_dev=1409480606, st_nlink=1, st_uid=0, st_gid=0, st_size=13595360, st_atime=1608549239, st_mtime=1591982925, st_ctime=1591982925)

# %%
print(os.stat('SalesKaggle.csv').st_size)
# Out:
# 13595360

# %%
print(os.stat('SalesKaggle.csv').st_mtime)
# Out:
# 1591982925.5974593

# %%
from datetime import datetime

mod_time = int(os.stat('SalesKaggle.csv').st_mtime)

print(datetime.fromtimestamp(mod_time))
# Out:
# 2020-06-12 22:58:45

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\Krishna\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-LTF8L2R',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CUDA_PATH': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.2',
#         'CUDA_PATH_V10_2': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.2',
#         'CUDA_PATH_V11_2': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.2',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\Krishna',
# ...

# %%
print(os.environ.get('HOMEPATH'))
# Out:
# \Users\Krishna

# %%
file_path = os.path.join(os.environ.get('HOMEPATH'), 'my_2test.txt')

# %%
#with open(file_path, 'w') as w:
    #f.wr
