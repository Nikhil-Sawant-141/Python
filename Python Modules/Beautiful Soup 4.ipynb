# %%
#Python program to scrape website 
#and save quotes from website 
import requests 
from bs4 import BeautifulSoup 
import csv 

URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 

quotes=[] # a list to store quotes 

table = soup.find('div', attrs = {'id':'all_quotes'}) 

for row in table.findAll('div', attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}): 
    quote = {} 
    quote['theme'] = row.h5.text 
    quote['url'] = row.a['href'] 
    quote['img'] = row.img['src'] 
    quote['lines'] = row.img['alt'].split(" #")[0] 
    quote['author'] = row.img['alt'].split(" #")[1] 
    quotes.append(quote)

# %%
quotes
# Out:
# [{'theme': 'CREATIVITY',
#   'url': '/inspirational-quotes/7812-curiosity-about-life-in-all-of-its-aspects-i',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/7812/medium/20200903_thursday_quote.jpg?1598565687',
#   'lines': 'Curiosity about life in all of its aspects, I think, is still the secret of great creative people.',
#   'author': '<Author:0x00007f0676260358>'},
#  {'theme': 'CREATIVITY',
#   'url': '/inspirational-quotes/8122-happiness-lies-in-the-joy-of-achievement-and',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8122/medium/20200902_wednesday_quote.jpg?1598565656',
#   'lines': 'Happiness lies in the joy of achievement and the thrill of creative effort.',
#   'author': '<Author:0x00007f0676271158>'},
#  {'theme': 'CREATIVITY',
#   'url': '/inspirational-quotes/8121-create-what-sets-your-heart-on-fire-and-it-will',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8121/medium/20200901_tuesday_quote.jpg?1598565635',
#   'lines': 'Create what sets your heart on fire and it will illuminate the path ahead.',
#   'author': '<Author:0x00007f0676282598>'},
#  {'theme': 'CREATIVITY',
#   'url': '/inspirational-quotes/8120-creativity-is-the-way-i-share-my-soul-with-the',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8120/medium/20200831_monday_quote.jpg?1598565613',
#   'lines': 'Creativity is the way I share my soul with the world.',
#   'author': '<Author:0x00007f067628d010>'},
#  {'theme': 'COURTESY',
#   'url': '/inspirational-quotes/8118-kindness-isnt-sacrifice-so-much-as-it-is-being',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8118/medium/20200828_friday_quote.jpg?1597869672',
#   'lines': "Kindness isn't sacrifice so much as it is being considerate for the feelings of others, sharing happiness, the unselfish thought, the spontaneous and friendly act, forgetfulness of our own present interests. ",
#   'author': '<Author:0x00007f067629f6c0>'},
#  {'theme': 'COURTESY',
#   'url': '/inspirational-quotes/8117-take-care-be-kind-be-considerate-of-other',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8117/medium/20200827_thursday_quote.jpg?1597869639',
#   'lines': 'Take care, be kind, be considerate of other people and other species, and be loving.',
#   'author': '<Author:0x00007f06762a9f30>'},
#  {'theme': 'COURTESY',
#   'url': '/inspirational-quotes/8116-real-strength-entails-being-considerate-and',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8116/medium/20200826_wednesday_quote.jpg?1597869555',
#   'lines': "Real strength entails being considerate and supportive of people's feelings.",
#   'author': '<Author:0x00007f06762b5038>'},
#  {'theme': 'COURTESY',
#   'url': '/inspirational-quotes/8119-life-is-short-but-there-is-always-time-enough',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8119/medium/20200825_tuesday_quote.jpg?1597869487',
#   'lines': 'Life is short but there is always time enough for courtesy.',
#   'author': '<Author:0x00007f06762c6d38>'},
#  {'theme': 'COURTESY',
#   'url': '/inspirational-quotes/7795-a-tree-is-known-by-its-fruit-a-person-by-their',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/7795/medium/20200824_monday_quote.jpg?1597868996',
#   'lines': 'A tree is known by its fruit; a person by their deeds. A good deed is never lost; whoever sows courtesy reaps friendship, and whoever plants kindness gathers love.',
#   'author': '<Author:0x00007f06762d1788>'},
#  {'theme': 'STRENGTH',
#   'url': '/inspirational-quotes/8114-if-you-were-born-with-the-weakness-to-fall-you',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8114/medium/20200821_friday_quote.jpg?1597353972',
#   'lines': 'If you were born with the weakness to fall. You were born with the strength to rise.',
#   'author': '<Author:0x00007f06762dc868>'},
#  {'theme': 'STRENGTH',
#   'url': '/inspirational-quotes/6926-maybe-who-we-are-isnt-so-much-about-what-we-do',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/6926/medium/20200820_thursday_quote.jpg?1597353926',
#   'lines': "Maybe who we are isn't so much about what we do, but rather what we're capable of when we least expect it.",
#   'author': '<Author:0x00007f06762ef3a0>'},
#  {'theme': 'STRENGTH',
#   'url': '/inspirational-quotes/8113-for-what-it-s-worth-it-s-never-too-late-to-be',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8113/medium/20200819_wednesday_quote.jpg?1597353876',
#   'lines': 'For what it’s worth: It’s never too late to be whoever you want to be. I hope you live a life you’re proud of, and if you find you’re not, I hope you have the strength to start over again.',
#   'author': '<Author:0x00007f06762fa3e0>'},
#  {'theme': 'STRENGTH',
#   'url': '/inspirational-quotes/8112-when-something-bad-happens-you-have-three',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8112/medium/20200818_tuesday_quote.jpg?1597353822',
#   'lines': 'When something bad happens you have three choices. You can let it define you, let it destroy you, or you can let it strengthen you.',
#   'author': '<Author:0x00007f0676304d68>'},
#  {'theme': 'STRENGTH',
#   'url': '/inspirational-quotes/8111-a-true-hero-isn-t-measured-by-the-size-of-their',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8111/medium/20200817_monday_quote.jpg?1597353760',
#   'lines': 'A true hero isn’t measured by the size of their strength, but by the strength of their heart.',
#   'author': '<Author:0x00007f0676317648>'},
#  {'theme': 'APPRECIATING NATURE',
#   'url': '/inspirational-quotes/8109-nature-has-been-for-me-for-as-long-as-i',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8109/medium/20200814_friday_quote.jpg?1596663210',
#   'lines': 'Nature has been for me, for as long as I remember, a source of solace, inspiration, adventure, and delight; a home, a teacher, a companion.',
#   'author': '<Author:0x00007f0676325db0>'},
#  {'theme': 'APPRECIATING NATURE',
#   'url': '/inspirational-quotes/8110-i-took-a-walk-in-the-woods-and-came-out-taller',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8110/medium/20200813_thursday_quote_alt2.jpg?1596841457',
#   'lines': 'I took a walk in the woods and came out taller than the trees.',
#   'author': '<Author:0x00007f0676336098>'},
#  {'theme': 'APPRECIATING NATURE',
#   'url': '/inspirational-quotes/8108-there-is-something-infinitely-healing-in-the',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8108/medium/rachel_carson_fixed.jpg?1597769516',
#   'lines': 'There is something infinitely healing in the repeated refrains of nature – the assurance that dawn comes after night, and spring after winter.',
#   'author': '<Author:0x00007f0676340660>'},
#  {'theme': 'APPRECIATING NATURE',
#   'url': '/inspirational-quotes/8107-a-walk-in-nature-walks-the-soul-back-home',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8107/medium/20200811_tuesday_quote.jpg?1596663032',
#   'lines': 'A walk in nature, walks the soul back home.',
#   'author': '<Author:0x00007f0676352b08>'},
#  {'theme': 'APPRECIATING NATURE',
#   'url': '/inspirational-quotes/7508-i-felt-my-lungs-inflate-with-the-onrush-of',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/7508/medium/20200810_monday_quote.jpg?1596662943',
#   'lines': 'I felt my lungs inflate with the onrush of scenery—air, mountains, trees, people. I thought, ‘This is what it is to be happy.’',
#   'author': '<Author:0x00007f0676363d40>'},
#  {'theme': 'PERSEVERANCE',
#   'url': '/inspirational-quotes/4746-it-always-seems-impossible-until-its-done',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/4746/medium/20200807_friday_quote.jpg?1596496094',
#   'lines': 'It always seems impossible until its done.',
#   'author': '<Author:0x00007f067636df98>'},
#  {'theme': 'PERSEVERANCE',
#   'url': '/inspirational-quotes/8105-great-things-come-from-hard-work-and',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8105/medium/20200806_thursday_quote.jpg?1596213320',
#   'lines': 'Great things come from hard work and perseverance. No excuses.',
#   'author': '<Author:0x00007f067637fc98>'},
#  {'theme': 'PERSEVERANCE',
#   'url': '/inspirational-quotes/3016-patience-and-perseverance-have-a-magical-effect',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/3016/medium/20200805_wednesday_quote.jpg?1596213293',
#   'lines': 'Patience and perseverance have a magical effect before which difficulties disappear and obstacles vanish.',
#   'author': '<Author:0x00007f0676389b08>'},
#  {'theme': 'PERSEVERANCE',
#   'url': '/inspirational-quotes/8104-today-if-anything-is-trying-to-hold-you-back',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8104/medium/20200804_tuesday_quote.jpg?1596213265',
#   'lines': 'Today if anything is trying to hold you back, give no attention to it. Get your hopes up, get your faith up, look up, and get ready to rise up.',
#   'author': '<Author:0x00007f067639a160>'},
#  {'theme': 'PERSEVERANCE',
#   'url': '/inspirational-quotes/3962-i-think-a-hero-is-an-ordinary-individual-who',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/3962/medium/20200803_monday_quote.jpg?1596213242',
#   'lines': 'I think a hero is an ordinary individual who finds strength to persevere and endure in spite of overwhelming obstacles.',
#   'author': '<Author:0x00007f06763a4318>'},
#  {'theme': 'LAUGHTER',
#   'url': '/inspirational-quotes/3123-a-smile-starts-on-the-lips-a-grin-spreads-to',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/3123/medium/20200331_friday_quote.jpg?1595634378',
#   'lines': 'A smile starts on the lips, A grin spreads to the eyes, A chuckle comes from the belly; But a good laugh bursts forth from the soul, Overflows, and bubbles all around.',
#   'author': '<Author:0x00007f06763c66e8>'},
#  {'theme': 'LAUGHTER',
#   'url': '/inspirational-quotes/8051-in-this-world-a-good-time-to-laugh-is-any-time',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8051/medium/20200330_thursday_quote.jpg?1595634324',
#   'lines': 'In this world, a good time to laugh is any time you can. ',
#   'author': '<Author:0x00007f06763e77f8>'},
#  {'theme': 'LAUGHTER',
#   'url': '/inspirational-quotes/6829-to-thrive-in-life-you-need-three-bones-a',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/6829/medium/20200329_wednesday_quote.jpg?1595634221',
#   'lines': 'To thrive in life you need three bones. A wishbone. A backbone. And a funny bone.',
#   'author': '<Author:0x00007f06763f14b0>'},
#  {'theme': 'LAUGHTER',
#   'url': '/inspirational-quotes/7465-what-soap-is-to-the-body-laughter-is-to-the-soul',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/7465/medium/20200328_tuesday_quote.jpg?1595634197',
#   'lines': 'What soap is to the body, laughter is to the soul.',
#   'author': '<Author:0x00007f06763fc1f8>'},
#  {'theme': 'LAUGHTER',
#   'url': '/inspirational-quotes/8050-i-honestly-think-its-the-thing-i-like-most-to',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8050/medium/20200327_monday_quote.jpg?1595634171',
#   'lines': "I honestly think it's the thing I like most, to laugh. It cures a multitude of ills. It's probably the most important thing in a person.",
#   'author': '<Author:0x00007f067640e718>'},
#  {'theme': 'CHARACTER',
#   'url': '/inspirational-quotes/8103-good-character-is-the-single-most-important',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8103/medium/20200724_friday_quote.jpg?1595011033',
#   'lines': 'Good character is the single most important attribute of a successful and worthy life.',
#   'author': '<Author:0x00007f067641c930>'},
#  {'theme': 'CHARACTER',
#   'url': '/inspirational-quotes/8102-just-as-we-develop-our-physical-muscles-through',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8102/medium/20200723_thursday_quote.jpg?1595011009',
#   'lines': 'Just as we develop our physical muscles through overcoming opposition – such as lifting weights – we develop our character muscles by overcoming challenges and adversity.',
#   'author': '<Author:0x00007f067642d988>'},
#  {'theme': 'CHARACTER',
#   'url': '/inspirational-quotes/8101-our-ability-to-handle-life-s-challenges-is-a',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8101/medium/20200722_wednesday_quote.jpg?1595010982',
#   'lines': 'Our ability to handle life’s challenges is a measure of our strength of character.',
#   'author': '<Author:0x00007f067643fc00>'}]

# %%
len(quotes)
# Out:
# 32

# %%
filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f: 
    w = csv.DictWriter(f,['theme','url','img','lines','author']) 
    w.writeheader()
    for quote in quotes: 
        w.writerow(quote)
